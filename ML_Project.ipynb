# %%
# Import libraries

# This sets the number of CPU threads to 1
# Used to control parallel processing
# Helps avoid:High CPU usage,System lag.Often used in ML to make execution more stable

OMP_NUM_THREADS = 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans   # unsupervised ML model
import warnings
warnings.filterwarnings("ignore")
#  ignore warnings ,Keeps output clean

# %%
df = pd.read_csv(r"Desktop/ML/Mall_Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# Select features
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]
X
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %%
# Scale data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.73899919, -0.43480148],
#        [-1.73899919,  1.19570407],
#        [-1.70082976, -1.71591298],
#        [-1.70082976,  1.04041783],
#        [-1.66266033, -0.39597992],
#        [-1.66266033,  1.00159627],
#        [-1.62449091, -1.71591298],
#        [-1.62449091,  1.70038436],
#        [-1.58632148, -1.83237767],
#        [-1.58632148,  0.84631002],
#        [-1.58632148, -1.4053405 ],
#        [-1.58632148,  1.89449216],
#        [-1.54815205, -1.36651894],
#        [-1.54815205,  1.04041783],
#        [-1.54815205, -1.44416206],
#        [-1.54815205,  1.11806095],
#        [-1.50998262, -0.59008772],
#        [-1.50998262,  0.61338066],
#        [-1.43364376, -0.82301709],
#        [-1.43364376,  1.8556706 ],
#        [-1.39547433, -0.59008772],
#        [-1.39547433,  0.88513158],
#        [-1.3573049 , -1.75473454],
#        [-1.3573049 ,  0.88513158],
#        [-1.24279661, -1.4053405 ],
#        [-1.24279661,  1.23452563],
#        [-1.24279661, -0.7065524 ],
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Apply KMeans
kmeans = KMeans(n_clusters = 5,random_state=42)     # KMean- Model , you can change n_clusters
kmeans.fit(X)     # traning
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
# Add cluster label to dataset
df["Cluster"] = kmeans.labels_
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster
# 0          4
# 1          2
# 2          4
# 3          2
# 4          4
# ...

# %%
plt.figure(figsize=(8,6))

plt.scatter(X['Annual Income (k$)'], 
            X['Spending Score (1-100)'],
            c=kmeans.labels_, cmap="rainbow",
            s=100, alpha=0.7, edgecolors="black")

plt.scatter(kmeans.cluster_centers_[:, 0], 
            kmeans.cluster_centers_[:, 1],
            color="black", marker="X",
            s=200, label="Centroid")

plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.title("K-Means Clustering of Mall Customers")

plt.legend()
plt.show()

# %%
# Elbow Method
WCSS = []  # Within Cluster Sum of Squares
for i in range(1, 11):  # test k from 1 to 10
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X)
    WCSS.append(kmeans.inertia_)  # inertia_ = sum of squared distances

WCSS
# Out:
# [269981.28,
#  183653.32894736843,
#  106348.37306211122,
#  73880.64496247195,
#  44448.4554479337,
#  40825.16946386947,
#  33642.57922077923,
#  26686.83778518779,
#  24766.471609793443,
#  23103.122085983916]

# %%
# !pip install kneed

# %% [raw]
# 1. k = range(1, 11)
# You are testing different cluster values:
# k = 1, 2, 3, ..., 10
#
# WCSS = Within-Cluster Sum of Squares
# 👉 It measures:How compact your clusters are (lower = better)
#
# When you plot:plt.plot(k, WCSS)
# You get an Elbow Curve 📉
# At first → WCSS drops sharply
# Then → improvement slows down.👉 The “bend” (elbow) = best k
#
# KneeLocator (from kneed) automatically finds that bend point.
#
# nee = KneeLocator(k, WCSS, curve="convex", direction="decreasing")
# Parameters:
# k → x-axis values
# WCSS → y-axis values
# curve="convex" → shape of elbow curve
# direction="decreasing" → because WCSS decreases
#
# print("Optimal k:", knee.knee)
# 👉 This gives the best number of clusters
#
# Instead of guessing k manually ❌
# 👉 You automate cluster selection ✅

# %%
from kneed import KneeLocator

k = range(1, 11)
knee = KneeLocator(k, WCSS, curve="convex", direction="decreasing")

print("Optimal k:", knee.knee)
# Out:
# Optimal k: 5

# %%
# Plot Elbow Curve
plt.plot(range(1, 11), wcss)
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
# Train final model
kmeans = KMeans(n_clusters=5, random_state=42)
# df['Cluster'] = kmeans.fit_predict(X_scaled)
kmeans.fit(X)     # traning
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
# Add cluster label to dataset
df["Cluster"] = kmeans.labels_
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster
# 0          4
# 1          2
# 2          4
# 3          2
# 4          4
# ...

# %%
# Visualize clusters
plt.scatter(df['Annual Income (k$)'], df['Spending Score (1-100)'], c=df['Cluster'])
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.title('Customer Segments')
plt.show()

# %% [raw]
# Streamlit app
#
# What App Will do?
#
# User inputs:Annual Income,Spending Score
# so App will:
#
# Predict which customer segment they belong to
# Show cluster visually
